# %%
from IPython.display import display 
from PIL import Image
from yolo import YOLO
import tensorflow

# %%
yolo = YOLO(model_path='logs/000/trained_weights_final.h5',
            classes_path='model_data/classes.txt')
# Out:
# logs/000/trained_weights_final.h5 model, anchors, and classes loaded.

# %%
image = Image.open('1.jpg')
result_image = yolo.detect_image(image)
display(result_image)
# Out:
# Found 2 boxes for img
# raccoon 0.92 (101, 75) (469, 281)
# raccoon 1.00 (0, 21) (594, 282)
# 4.255029300000001
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x300 at 0x2451C87B2C8>
